# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
from sklearn.model_selection import KFold, cross_val_score, RandomizedSearchCV, GridSearchCV

# %%
df= pd.read_csv('./data/train_preprocessed.csv')
scaler = StandardScaler()
X=scaler.fit_transform(df.drop('SalePrice', axis=1))
X_train, X_test, y_train, y_test = train_test_split(df.drop('SalePrice',axis =1), df['SalePrice'], test_size=0.2, random_state=0)

# %%
model = XGBRegressor(subsample= 0.6,n_estimators=500, min_child_weight= 1, max_depth= 4, learning_rate= 0.01, gamma=1.5, colsample_bytree= 0.8)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=1.5, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
print(mean_squared_error(predictions, y_test))
print(r2_score(y_test, y_pred))
# Out:
# 811826315.7773973
# 0.8824435472488403

# %%
cv = KFold(n_splits=5, random_state=1, shuffle=True)
scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='r2')

# %%
print(scores)
scores.mean()
# Out:
# [0.93299788 0.77586806 0.89375132 0.88200676 0.88745505]
# np.float64(0.8744158148765564)

# %%
params = {
        'learning_rate': [0.01, 0.05, 0.1],
        'n_estimators': [100, 500, 1000],
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

model_test = XGBRegressor(random_state=0)

skf = KFold(n_splits=5, shuffle = True, random_state = 0)

folds = 3
param_comb = 7
random_search = RandomizedSearchCV(model_test, param_distributions=params, n_iter=param_comb, scoring='r2', n_jobs=-1, cv=skf, verbose=3, random_state=0 )
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.930 total time=   1.2s[CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.741 total time=   1.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.896 total time=   1.2s
#
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.869 total time=   1.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.6;, score=0.889 total time=   1.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.6;, score=0.893 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.6;, score=0.901 total time=   1.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.6;, score=0.924 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.6;, score=0.716 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.5, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=1000, subsample=0.6;, score=0.869 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.757 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.904 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.869 total time=   1.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.896 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.732 total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.887 total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.896 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.916 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.6;, score=0.900 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.860 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.905 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.861 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.923 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.899 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=1000, subsample=0.8;, score=0.746 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.921 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.874 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.891 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.781 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=1.5, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.906 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.890 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.908 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.928 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.893 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000, subsample=0.8;, score=0.750 total time=   1.1s
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None...
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=0, ...),
#                    n_iter=7, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [3, 4, 5],
#                                         'min_child_weight': [1, 5, 10],
#                                         'n_estimators': [100, 500, 1000],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=0, scoring='r2', verbose=3)

# %%
print('\n Best hyperparameters:')
print(random_search.best_params_)
# Out:
#  Best hyperparameters:
# {'subsample': 0.6, 'n_estimators': 500, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.01, 'gamma': 1.5, 'colsample_bytree': 0.8}

# %%
params = {
        'learning_rate': [0.01, 0.05, 0.1],
        'n_estimators': [100, 500, 800],
        'min_child_weight': [1, 5, 10],
        'gamma': [1, 1.5, 2],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

model_test = XGBRegressor(random_state=0)

skf = KFold(n_splits=5, shuffle = True, random_state = 0)
grid = GridSearchCV(model_test, param_grid=params, scoring='r2', n_jobs=-1, cv=skf, verbose=4)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2187 candidates, totalling 10935 fits
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.678 total time=   0.3s[CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.671 total time=   0.3s
#
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.675 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.630 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.607 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.679 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.629 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.688 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.678 total time=   0.4s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.675 total time=   0.4s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.675 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.612 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.630 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.669 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.613 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.886 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.863 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.897 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.864 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.768 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.914 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.915 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.885 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.761 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.908 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.862 total time=   0.5s[CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.898 total time=   0.5s
#
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.887 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.894 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.760 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.679 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.611 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.671 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.631 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.673 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.926 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.880 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.676 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.898 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.902 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.611 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.749 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.676 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.674 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.630 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.672 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.605 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.681 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.630 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.672 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.925 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.879 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.916 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.905 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.895 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.899 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.883 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.743 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.903 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.748 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.913 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.857 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.882 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.898 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.791 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.912 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.876 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.850 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.779 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.897 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.910 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.841 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.867 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.774 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.900 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.677 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.680 total time=   0.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.612 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.635 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.672 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.923 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.868 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.894 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.772 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.675 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.906 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.630 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.609 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.674 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.677 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.675 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.608 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.677 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.633 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.923 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.866 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.671 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.906 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.763 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.884 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.920 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.860 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.877 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.764 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.909 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.911 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.888 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.821 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.902 total time=   0.5s[CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.859 total time=   0.5s
#
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.911 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.852 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.806 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.883 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.880 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.911 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.899 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.801 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.847 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.899 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.710 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.633 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.695 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.650 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.897 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.922 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.703 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.868 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.811 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.910 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.705 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.639 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.695 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.658 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.921 total time=   0.7s[CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.702 total time=   0.2s
#
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.792 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.704 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.861 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.892 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.638 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.699 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.907 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.658 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.700 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.857 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.921 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.787 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.889 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.907 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.922 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.892 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.902 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.870 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.919 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.769 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.783 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.878 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.904 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.885 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.878 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.911 total time=   0.8s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.888 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.760 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.898 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.705 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.689 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.632 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.655 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.6;, score=0.704 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.930 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.904 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.770 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.882 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.900 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.702 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.693 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.633 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.659 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.704 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.711 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.632 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.695 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.664 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.700 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.891 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.907 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.927 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.888 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.918 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.755 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.889 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.918 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.894 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.862 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.751 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.903 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.887 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.797 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.917 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.905 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.790 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.879 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.859 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.904 total time=   0.7s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.914 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.786 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.854 total time=   0.7s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.867 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.901 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.703 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.630 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.702 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.910 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.659 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.924 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.869 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.702 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.896 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.924 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.702 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.778 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.633 total time=   0.2s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.701 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.909 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.871 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.884 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.772 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.659 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.706 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.633 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.704 total time=   0.2s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.871 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.698 total time=   0.2s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.921 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.661 total time=   0.2s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.703 total time=   0.2s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.769 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.906 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.874 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.917 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.857 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.907 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.830 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.905 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.915 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.895 total time=   0.7s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.818 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.858 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.888 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.910 total time=   0.6s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.813 total time=   0.6s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.880 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.856 total time=   0.7s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.901 total time=   0.7s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.862 total time=   0.8s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.644 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.723 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.901 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.924 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.695 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.912 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.817 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.657 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.6;, score=0.713 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.721 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.652 total time=   0.3s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.717 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.708 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.665 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.723 total time=   0.3s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.653 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.701 total time=   0.3s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.666 total time=   0.3s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.923 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.709 total time=   0.3s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.895 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.864 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.910 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.803 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.887 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.916 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.864 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.799 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.906 total time=   0.9s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.926 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.891 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.874 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.900 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.6;, score=0.792 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.922 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.889 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.780 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.903 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.6, gamma=1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.877 total time=   1.2s
# ...
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.882 total time=   3.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.896 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.875 total time=   3.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.6;, score=0.909 total time=   3.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.899 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.908 total time=   1.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.894 total time=   1.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.865 total time=   1.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.866 total time=   3.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.6;, score=0.712 total time=   1.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.910 total time=   3.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.911 total time=   1.7s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.871 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.905 total time=   3.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.717 total time=   1.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.766 total time=   3.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.901 total time=   1.7s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.871 total time=   3.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.883 total time=   3.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.726 total time=   3.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.874 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.892 total time=   3.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=0.8;, score=0.898 total time=   3.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=800, subsample=1.0;, score=0.898 total time=   3.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.881 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.910 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.859 total time=   1.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.747 total time=   1.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.895 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.917 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.896 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.865 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.914 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.6;, score=0.801 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.911 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.856 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.897 total time=   0.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.906 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=0.8;, score=0.789 total time=   0.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.899 total time=   2.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.906 total time=   2.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.865 total time=   2.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.901 total time=   0.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.894 total time=   2.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.6;, score=0.712 total time=   2.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.909 total time=   2.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.853 total time=   0.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.871 total time=   2.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.883 total time=   0.4s[CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.911 total time=   2.6s
#
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.908 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=100, subsample=1.0;, score=0.784 total time=   0.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.717 total time=   2.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.859 total time=   2.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.881 total time=   2.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.900 total time=   2.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=0.8;, score=0.874 total time=   2.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.747 total time=   2.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=800, subsample=1.0;, score=0.895 total time=   2.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.912 total time=   1.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.853 total time=   1.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.888 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.908 total time=   1.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.6;, score=0.720 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.900 total time=   1.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.895 total time=   1.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.913 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.857 total time=   1.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.904 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.855 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.903 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=0.8;, score=0.723 total time=   1.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.888 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=500, subsample=1.0;, score=0.751 total time=   1.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.849 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.909 total time=   1.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.885 total time=   1.9s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.906 total time=   1.8s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.6;, score=0.715 total time=   2.0s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.911 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.856 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.895 total time=   1.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.898 total time=   1.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=0.8;, score=0.721 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.904 total time=   1.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.887 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.902 total time=   1.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.750 total time=   1.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=2, learning_rate=0.1, max_depth=5, min_child_weight=10, n_estimators=800, subsample=1.0;, score=0.854 total time=   1.6s
# /home/miza/housepricesml/.venv/lib/python3.10/site-packages/numpy/ma/core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     inter...
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=0, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [1, 1.5, 2],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 4, 5], 'min_child_weight': [1, 5, 10],
#                          'n_estimators': [100, 500, 800],
#                          'subsample': [0.6, 0.8, 1.0]},
#              scoring='r2', verbose=4)

# %%
print('\n Best estimator:')
print(grid.best_estimator_)
print('\n Best score:')
print(grid.best_score_)
print('\n Best parameters:')
print(grid.best_params_)
# Out:
#  Best estimator:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)
#
#  Best score:
# 0.885656189918518
#
#  Best parameters:
# {'colsample_bytree': 0.8, 'gamma': 1, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 10, 'n_estimators': 100, 'subsample': 0.6}

# %%
print(random_search.best_params_)
# Out:
# {'subsample': 0.6, 'n_estimators': 500, 'min_child_weight': 1, 'max_depth': 4, 'learning_rate': 0.01, 'gamma': 1.5, 'colsample_bytree': 0.8}
